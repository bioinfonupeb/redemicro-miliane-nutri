# %%
import os
import pandas as pd

# %matplotlib inline

# %%
study = 'miliane-AxAC'
data_path = os.path.join('..', 'data', 'raw')

# %% [markdown]
# ## Data ingestion

# %%
samples_names_fpath = os.path.join(data_path, 'sample_id-sample_name.tsv')
samples_names_df =  pd.read_csv(samples_names_fpath, delimiter='\t')
samples_names_df['sample-id'] = samples_names_df['sample-id'].astype('int64')
print(samples_names_df)
# Out:
#        sample-id sample-name
# 0   210421121673    #1 N9.01
# 1   210421121674   #2 N11.01
# 2   210421121675    #3 N9.05
# 3   210421121676   #4 N11.02
# 4   210421121677    #5 N9.03
# ..           ...         ...
# 69  210707163913  #70 7d.AM2
# 70  210707163914   #71 7d.C3
# 71  210707163915   #72 7d.M3
# 72  210707163916   #73 7d.A3
# 73  210707163917  #74 7d.AM3
#
# [74 rows x 2 columns]

# %%
samples_paths_fpath = os.path.join(data_path, 'samples-paths.tsv')
samples_paths_df =  pd.read_csv(samples_paths_fpath, delimiter='\t')
samples_paths_df['sample-id'] = samples_paths_df['sample-id'].astype('int64')
print(samples_paths_df)
# Out:
#         sample-id                                  absolute-filepath direction
# 0    210421121673  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   forward
# 1    210421121673  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   reverse
# 2    210421121674  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   forward
# 3    210421121674  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   reverse
# 4    210421121675  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   forward
# ..            ...                                                ...       ...
# 143  210707163915  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   reverse
# 144  210707163916  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   forward
# 145  210707163916  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   reverse
# 146  210707163917  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   forward
# 147  210707163917  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   reverse
#
# [148 rows x 3 columns]

# %% [markdown]
# ## Data transform
#
# Combine Dataframes and organize all sample data in one DataFrame.

# %%
rows = list()
cols = ['sample-id', 'forward-path', 'reverse-path']
df = samples_paths_df
for i in range(0,len(df.index),2):
    r1 = df.iloc[i,:]
    r2 = df.iloc[i+1,:]
    new_row = (r1[0], r1[1], r2[1])
    rows.append(new_row)
new_df = pd.DataFrame(rows, columns=cols)
new_df['sample-id'] = new_df['sample-id'].astype('int64')
print(new_df)
# Out:
#        sample-id                                       forward-path  \
# 0   210421121673  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 1   210421121674  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 2   210421121675  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 3   210421121676  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 4   210421121677  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# ..           ...                                                ...
# 69  210707163913  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 70  210707163914  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 71  210707163915  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 72  210707163916  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 73  210707163917  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
#
#                                          reverse-path
# 0   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 1   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 2   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 3   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 4   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# ..                                                ...
# 69  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 70  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 71  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 72  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 73  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
#
# [74 rows x 3 columns]

# %%
joined_df = pd.concat([samples_names_df, new_df], axis=1)
joined_df = joined_df.loc[:,~joined_df.columns.duplicated()].copy()
print(joined_df)
# Out:
#        sample-id sample-name  \
# 0   210421121673    #1 N9.01
# 1   210421121674   #2 N11.01
# 2   210421121675    #3 N9.05
# 3   210421121676   #4 N11.02
# 4   210421121677    #5 N9.03
# ..           ...         ...
# 69  210707163913  #70 7d.AM2
# 70  210707163914   #71 7d.C3
# 71  210707163915   #72 7d.M3
# 72  210707163916   #73 7d.A3
# 73  210707163917  #74 7d.AM3
#
#                                          forward-path  \
# 0   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 1   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 2   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 3   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 4   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# ..                                                ...
# 69  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 70  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 71  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 72  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 73  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
#
#                                          reverse-path
# 0   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 1   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 2   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 3   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 4   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# ..                                                ...
# 69  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 70  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 71  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 72  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 73  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
#
# [74 rows x 4 columns]

# %%
manifest_df = joined_df[['sample-id', 'forward-path', 'reverse-path']]
print(manifest_df)
# Out:
#        sample-id                                       forward-path  \
# 0   210421121673  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 1   210421121674  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 2   210421121675  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 3   210421121676  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 4   210421121677  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# ..           ...                                                ...
# 69  210707163913  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 70  210707163914  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 71  210707163915  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 72  210707163916  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 73  210707163917  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
#
#                                          reverse-path
# 0   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 1   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 2   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 3   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 4   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# ..                                                ...
# 69  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 70  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 71  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 72  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 73  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
#
# [74 rows x 3 columns]

# %% [markdown]
# ## Load data
#
# Save new manifest as a TSV file.

# %%
fpath = os.path.join(data_path, 'karina-samples-groups.tsv')
manifest_df.to_csv(fpath, sep=',', index=False)

# %% [markdown]
# ### Data reduction
#
# Select context group samples.

# %%
groups_path = os.path.join(data_path, 'miliane-samples-groups.tsv')
study_df = pd.read_csv(groups_path, sep='\t')
key = ('sample-name', )
study_df = study_df.join(joined_df.set_index(key[0]), on=key[0])
study_df
# Out:
#    sample-name group-id               group-desc     sample-id  \
# 0    #39 N1.04        C           Grupo controle  210421121711
# 1    #40 N3.09        C           Grupo controle  210421121712
# 2    #41 N1.03        C           Grupo controle  210421121713
# 3    #42 N2.02        C           Grupo controle  210421121714
# 4    #43 N2.07        C           Grupo controle  210421121715
# 5    #44 N3.08        C           Grupo controle  210421121716
# 6    #45 N2.08       AC  Grupo acetato de chumbo  210421121717
# 7    #46 N2.11       AC  Grupo acetato de chumbo  210421121718
# 8    #47 N2.12       AC  Grupo acetato de chumbo  210421121719
# 9    #48 N3.03       AC  Grupo acetato de chumbo  210421121720
# 10   #49 N3.07       AC  Grupo acetato de chumbo  210421121721
# 11   #50 N3.11       AC  Grupo acetato de chumbo  210421121722
#
#                                          forward-path  \
# 0   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 1   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 2   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 3   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 4   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 5   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 6   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 7   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 8   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 9   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 10  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 11  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
#
#                                          reverse-path
# 0   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 1   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 2   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 3   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 4   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 5   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 6   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 7   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 8   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 9   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 10  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 11  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...

# %%
selected_cols = ['sample-id', 'sample-name', 'sample-group']
selected_cols = ['sample-id', 'sample-name', 'group-id', 'group-desc']
metadata_df = study_df[selected_cols]
metadata_df
# Out:
#        sample-id sample-name group-id               group-desc
# 0   210421121711   #39 N1.04        C           Grupo controle
# 1   210421121712   #40 N3.09        C           Grupo controle
# 2   210421121713   #41 N1.03        C           Grupo controle
# 3   210421121714   #42 N2.02        C           Grupo controle
# 4   210421121715   #43 N2.07        C           Grupo controle
# 5   210421121716   #44 N3.08        C           Grupo controle
# 6   210421121717   #45 N2.08       AC  Grupo acetato de chumbo
# 7   210421121718   #46 N2.11       AC  Grupo acetato de chumbo
# 8   210421121719   #47 N2.12       AC  Grupo acetato de chumbo
# 9   210421121720   #48 N3.03       AC  Grupo acetato de chumbo
# 10  210421121721   #49 N3.07       AC  Grupo acetato de chumbo
# 11  210421121722   #50 N3.11       AC  Grupo acetato de chumbo

# %%
manifest_df.columns
# Out:
# Index(['sample-id', 'forward-path', 'reverse-path'], dtype='object')

# %%
manifest_df = study_df[['sample-id', 'forward-path', 'reverse-path']]
manifest_df= manifest_df.rename(columns = {'sample-id': '#SampleID'})
headers = [manifest_df.columns, ['#q2:types', 'categorical', 'categorical']]
manifest_df.columns = headers
manifest_df
# Out:
#        #SampleID                                       forward-path  \
#        #q2:types                                        categorical
# 0   210421121711  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 1   210421121712  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 2   210421121713  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 3   210421121714  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 4   210421121715  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 5   210421121716  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 6   210421121717  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 7   210421121718  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 8   210421121719  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 9   210421121720  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 10  210421121721  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 11  210421121722  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
#
#                                          reverse-path
#                                           categorical
# 0   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 1   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 2   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 3   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 4   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 5   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 6   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 7   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 8   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 9   /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 10  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...
# 11  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...

# %% [markdown]
# ## Load Reduced Data

# %%
metadata_path = os.path.join(data_path, 'metadata', 'miliane-metadata-CxAC.tsv')
metadata_df.to_csv(metadata_path, sep='\t', index=False)

manifest_path = os.path.join(data_path, 'manifest', 'miliane-manifest-CxAC.csv')
manifest_df.to_csv(manifest_path, sep=',', index=False)

# %%
manifest_02_df = samples_paths_df[samples_paths_df['sample-id'].isin(manifest_df['#SampleID']['#q2:types'])]
manifest_02_df
# Out:
#        sample-id                                  absolute-filepath direction
# 76  210421121711  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   forward
# 77  210421121711  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   reverse
# 78  210421121712  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   forward
# 79  210421121712  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   reverse
# 80  210421121713  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   forward
# 81  210421121713  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   reverse
# 82  210421121714  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   forward
# 83  210421121714  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   reverse
# 84  210421121715  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   forward
# 85  210421121715  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   reverse
# 86  210421121716  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   forward
# 87  210421121716  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   reverse
# 88  210421121717  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   forward
# 89  210421121717  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   reverse
# 90  210421121718  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   forward
# 91  210421121718  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   reverse
# 92  210421121719  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   forward
# 93  210421121719  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   reverse
# 94  210421121720  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   forward
# 95  210421121720  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   reverse
# 96  210421121721  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   forward
# 97  210421121721  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   reverse
# 98  210421121722  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   forward
# 99  210421121722  /home/lauro/nupeb/dados_brutos_rede_genoma/dat...   reverse

# %%
manifest_path = os.path.join(data_path, 'manifest', 'miliane-manifest-CxAC.csv')
manifest_02_df.to_csv(manifest_path, sep=',', index=False)
